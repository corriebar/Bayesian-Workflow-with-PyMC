# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import altair as alt
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
d = pd.read_csv("../data/interim_data/houses.csv", dtype = {"ags": str, "plz": str}, index_col=0)

# %%
d.drop(columns=["lat", "lng"]).head()
# Out:
#                      ags    zip     price    sqm_price  log_sqm_price  \
# 3   11000000001000000094  12489  180000.0  2246.069379       7.716937
# 4   11000000001000000094  12489   87000.0  1740.000000       7.461640
# 6   11000000001000000140  12489  101200.0  3066.666667       8.028346
# 9   11000000001000000140  12489  148400.0  3420.142890       8.137438
# 10  11000000001000000140  12489  261200.0  3374.677003       8.124055
#
#     living_space  sale_year  sale_month  const_year objecttype housetype  \
# 3          80.14       2018           8      1936.0       flat       NaN
# 4          50.00       2017           7      1910.0       flat       NaN
# 6          33.00       2016           4      2016.0       flat       NaN
# 9          43.39       2017           1      2017.0       flat       NaN
# 10         77.40       2016           6      2016.0       flat       NaN
#
#        usage  interior_qual
# 3   rent_out         normal
# 4   rent_out            NaN
# 6   rent_out            NaN
# 9   rent_out  sophisticated
# 10  rent_out  sophisticated

# %%
alt.Chart(d).mark_bar().encode(
    alt.X("sqm_price:Q", 
            bin=alt.BinParams(maxbins=100)),
    y="count()"
)
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
